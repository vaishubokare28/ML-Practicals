# %% [markdown]
# ML PRACRICAL 2. Assignment on Regression technique

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
#Load dataset
df = pd.read_csv("temperatures.csv")

# %%
# Display first few records
print("First 5 rows of the dataset:\n")
print(df.head(), "\n")
# Out:
# First 5 rows of the dataset:
#
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %% [markdown]
# a. Apply Linear Regression using suitable library function and predict the Month-wise temperature

# %%
#Select required columns (Year vs Annual Temperature)
#input data
x = df[["YEAR"]]  #Independent variable

#output data
y = df["ANNUAL"] #Dependent variable

# %%
#Create and train Linear Regression model
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
#Predict annual temperature
y_pred = model.predict(x)

# %% [markdown]
# b. Assess the performance of regression models using MSE, MAE and R-Square metrics

# %%
#Evaluate model performance
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("Model Performance Metrics:")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-Squared (R²): {r2:.4f}\n")
# Out:
# Model Performance Metrics:
# Mean Squared Error (MSE): 0.1096
# Mean Absolute Error (MAE): 0.2254
# R-Squared (R²): 0.6418

# %% [markdown]
# c. Visualize simple regression model.

# %%
#Visualize regression model
plt.figure(figsize=(10,6))
sns.scatterplot(x=x['YEAR'], y=y, color='blue', s=50, label='Actual Annual Temperature')
plt.plot(x, y_pred, color='red', linewidth=2, label='Regression Line')
plt.title("Yearly Temperature Trend in India (1901 - Present)", fontsize=14, weight='bold')
plt.xlabel("Year")
plt.ylabel("Annual Average Temperature (°C)")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Future Prediction
future_years = pd.DataFrame({'YEAR': [2030, 2040, 2050]})
future_pred = model.predict(future_years)

print("\nPredicted Temperatures for Future Years:")
for yr, temp in zip(future_years['YEAR'], future_pred):
    print(f"Year {yr}: Predicted Temperature = {temp:.2f} °C")
# Out:
# Predicted Temperatures for Future Years:
# Year 2030: Predicted Temperature = 30.11 °C
# Year 2040: Predicted Temperature = 30.24 °C
# Year 2050: Predicted Temperature = 30.38 °C
